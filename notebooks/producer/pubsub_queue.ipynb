# %% [markdown]
# ## **Install the dependency packages**

# %%
# !python -m venv .venv
# !.venv\Scripts\Activate.ps1
# !pip install google-cloud-pubsub python-dotenv pandas
# Out:
# zsh:1: command not found: .venvScriptsActivate.ps1
# Requirement already satisfied: google-cloud-pubsub in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (2.33.0)
# Requirement already satisfied: python-dotenv in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (1.2.1)
# Requirement already satisfied: pandas in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (2.3.3)
# Requirement already satisfied: grpcio<2.0.0,>=1.75.1 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from google-cloud-pubsub) (1.76.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from google-cloud-pubsub) (2.43.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2.28.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.0 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from google-cloud-pubsub) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from google-cloud-pubsub) (6.33.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from google-cloud-pubsub) (0.14.3)
# Requirement already satisfied: grpcio-status>=1.33.2 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from google-cloud-pubsub) (1.76.0)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from google-cloud-pubsub) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.27.0 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from google-cloud-pubsub) (1.38.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2.32.5)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (4.9.1)
# Requirement already satisfied: typing-extensions~=4.12 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from grpcio<2.0.0,>=1.75.1->google-cloud-pubsub) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (0.6.1)
# Requirement already satisfied: numpy>=1.26.0 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from pandas) (2025.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from opentelemetry-api>=1.27.0->google-cloud-pubsub) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.27.0->google-cloud-pubsub) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from opentelemetry-sdk>=1.27.0->google-cloud-pubsub) (0.59b0)
# Requirement already satisfied: six>=1.5 in /Users/robogod/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ## **Import Function**

# %%
import pandas as pd
import json, pathlib, os, csv
from google.cloud import pubsub_v1

# %% [markdown]
# ## **Initialization**

# %%
PROJECT_ID = "iisc-data-engineering-project"
TOPIC_ID = "match_data"
SUBSCRIPTION_ID = "match_data-sub"
matches_FILE = "../../data/raw/matches.csv"
deliveries_FILE = "../../data/raw/deliveries.csv"
batch_setting = pubsub_v1.types.BatchSettings(
    max_bytes=5*1024*1024,  # Maximum bytes to batch
    max_messages=1000,  # Maximum number of messages to batch
    max_latency=0.5,  # Maximum latency in seconds
)
publisher = pubsub_v1.PublisherClient(batch_settings=batch_setting)
topic_path = publisher.topic_path(PROJECT_ID, TOPIC_ID)
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[5], line 11
#       5 deliveries_FILE = "data/raw/deliveries.csv"
#       6 batch_setting = pubsub_v1.types.BatchSettings(
#       7     max_bytes=5*1024*1024,  # Maximum bytes to batch
#       8     max_messages=1000,  # Maximum number of messages to batch
#       9     max_latency=0.5,  # Maximum latency in seconds
#      10 )
# ---> 11 publisher = pubsub_v1.PublisherClient(batch_settings=batch_setting)
#      12 topic_path = publisher.topic_path(PROJECT_ID, TOPIC_ID)
#
# File ~/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages/google/cloud/pubsub_v1/publisher/client.py:147, in Client.__init__(self, batch_settings, publisher_options, **kwargs)
#     143 self._enable_message_ordering = self.publisher_options[0]
#     145 # Add the metrics headers, and instantiate the underlying GAPIC
#     146 # client.
# --> 147 super().__init__(**kwargs)
#     148 self._target = self._transport._host
#     149 self._batch_class = thread.Batch
#
# File ~/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages/google/pubsub_v1/services/publisher/client.py:775, in PublisherClient.__init__(self, credentials, transport, client_options, client_info)
#     772             channel = grpc.aio.insecure_channel(target=emulator_host)
#     773         transport_init = functools.partial(transport_init, channel=channel)
# --> 775     self._transport = transport_init(
#     776         credentials=credentials,
#     777         credentials_file=self._client_options.credentials_file,
#     778         host=self._api_endpoint,
#     779         scopes=self._client_options.scopes,
#     780         client_cert_source_for_mtls=self._client_cert_source,
#     781         quota_project_id=self._client_options.quota_project_id,
#     782         client_info=client_info,
#     783         always_use_jwt_access=True,
#     784         api_audience=self._client_options.api_audience,
#     785     )
#     787 if "async" not in str(self._transport):
#     788     if CLIENT_LOGGING_SUPPORTED and _LOGGER.isEnabledFor(
#     789         std_logging.DEBUG
#     790     ):  # pragma: NO COVER
#
# File ~/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages/google/pubsub_v1/services/publisher/transports/grpc.py:238, in PublisherGrpcTransport.__init__(self, host, credentials, credentials_file, scopes, channel, api_mtls_endpoint, client_cert_source, ssl_channel_credentials, client_cert_source_for_mtls, quota_project_id, client_info, always_use_jwt_access, api_audience)
#     233             self._ssl_channel_credentials = grpc.ssl_channel_credentials(
#     234                 certificate_chain=cert, private_key=key
#     235             )
#     237 # The base transport sets the host, credentials and scopes
# --> 238 super().__init__(
#     239     host=host,
#     240     credentials=credentials,
#     241     credentials_file=credentials_file,
#     242     scopes=scopes,
#     243     quota_project_id=quota_project_id,
#     244     client_info=client_info,
#     245     always_use_jwt_access=always_use_jwt_access,
#     246     api_audience=api_audience,
#     247 )
#     249 if not self._grpc_channel:
#     250     # initialize with the provided callable or the default channel
#     251     channel_init = channel or type(self).create_channel
#
# File ~/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages/google/pubsub_v1/services/publisher/transports/base.py:111, in PublisherTransport.__init__(self, host, credentials, credentials_file, scopes, quota_project_id, client_info, always_use_jwt_access, api_audience, **kwargs)
#     107     credentials, _ = google.auth.load_credentials_from_file(
#     108         credentials_file, **scopes_kwargs, quota_project_id=quota_project_id
#     109     )
#     110 elif credentials is None and not self._ignore_credentials:
# --> 111     credentials, _ = google.auth.default(
#     112         **scopes_kwargs, quota_project_id=quota_project_id
#     113     )
#     114     # Don't apply audience if the credentials file passed from user.
#     115     if hasattr(credentials, "with_gdch_audience"):
#
# File ~/Code/iisc/Data_Engg_Project_IPL_Match_Prediction/.venv/lib/python3.14/site-packages/google/auth/_default.py:739, in default(scopes, request, quota_project_id, default_scopes)
#     731             _LOGGER.warning(
#     732                 "No project ID could be determined. Consider running "
#     733                 "`gcloud config set project` or setting the %s "
#     734                 "environment variable",
#     735                 environment_vars.PROJECT,
#     736             )
#     737         return credentials, effective_project_id
# --> 739 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.

# %% [markdown]
# ## **Two dataset are used of the following structure. The dataset is from IPL 2008-2024**
# 1. Matches  - Contains Match level data, Each row represents a single IPL match, including venue, teams, toss results, match outcomes, and player awards.
# 2. Deliveries - Each row represents one delivery (ball) in an IPL match. It links to matches.csv via the match_id column.
# Data Set Size
# 1. Matches - 1094 Match Entries
# 2. Deliveries -  260919 Deliveriy Entries

# %% [markdown]
# **Matches Schema Data**
#
# | Field | Description |
# |:--|:--|
# | **id** | Unique match identifier |
# | **season** | IPL season year |
# | **city** | Venue city |
# | **date** | Date of the match |
# | **match_type** | Type of match (League/Qualifier/Final) |
# | **player_of_match** | Player awarded “Man of the Match” |
# | **venue**| Stadium name |
# | **team1** | Home team |
# | **team2** | Away team |
# | **toss_winner** | Team that won the toss |
# | **toss_decision** | Toss decision (bat/field) |
# | **winner** | Match-winning team |
# | **result** | How the match was decided |
# | **result_margin** | Margin of victory (in runs or wickets) |
# | **target_runs** | Target set for the chasing team |
# | **target_overs** | Overs for the target innings |
# | **super_over** | Whether a Super Over occurred |
# | **method** | Method (Duckworth-Lewis, etc.), if applicable |
# | **umpire1** | First on-field umpire |
# | **umpire2** | Second on-field umpire |
#
#
# > ```json
# > {
# >   "eventType": "match",
# >   "payload": {
# >     "id": 980933,
# >     "season": "2016",
# >     "city": "Delhi",
# >     "date": "2016-04-23",
# >     "match_type": "League",
# >     "player_of_match": "SV Samson",
# >     "venue": "Feroz Shah Kotla",
# >     "team1": "Delhi Daredevils",
# >     "team2": "Mumbai Indians",
# >     "toss_winner": "Mumbai Indians",
# >     "toss_decision": "field",
# >     "winner": "Delhi Daredevils",
# >     "result": "runs",
# >     "result_margin": 10.0,
# >     "target_runs": 165.0,
# >     "target_overs": 20.0,
# >     "super_over": "N",
# >     "method": "NaN",
# >     "umpire1": "S Ravi",
# >     "umpire2": "C Shamshuddin"
# >   }
# > }
# > ```
#
# ---

# %% [markdown]
# **Deliveries Dataset**
#
# | Field | Description |
# |:--|:--|
# | **match_id** | Identifier linking delivery to its match |
# | **inning** | Inning number (1 or 2) |
# | **batting_team** | Team currently batting |
# | **bowling_team** | Team currently bowling |
# | **over** | Over number in the innings |
# | **ball** | Ball number within the over |
# | **batter** | Name of the batsman on strike |
# | **bowler** | Name of the bowler delivering the ball |
# | **non_striker** | Name of the non-striker batsman |
# | **batsman_runs** | Runs scored by the batsman from the delivery |
# | **extra_runs** | Runs awarded as extras (wide, no-ball, bye, etc.) |
# | **total_runs** | Total runs scored off the delivery (batsman + extras) |
# | **extras_type** | Type of extra (if any) — e.g., wides, byes |
# | **is_wicket** | Indicates if a wicket fell on this delivery (0/1) |
# | **player_dismissed** | Name of player dismissed, if any |
# | **dismissal_kind** | Type of dismissal (bowled, caught, etc.) |
# | **fielder** | Name of fielder involved in the dismissal |
#
#
# ```json
# {
#   "eventType": "deliveries",
#   "payload": {
#     "match_id": "1136597",
#     "inning": "1",
#     "batting_team": "Mumbai Indians",
#     "bowling_team": "Kolkata Knight Riders",
#     "over": "4",
#     "ball": "3",
#     "batter": "RV Uthappa",
#     "bowler": "MJ McClenaghan",
#     "non_striker": "N Rana",
#     "batsman_runs": "1",
#     "extra_runs": "0",
#     "total_runs": "1",
#     "extras_type": "",
#     "is_wicket": "0",
#     "player_dismissed": "NA",
#     "dismissal_kind": "NA",
#     "fielder": "NA"
#   }
# }

# %%
matches = pd.read_csv(matches_FILE)
deliveries = pd.read_csv(deliveries_FILE)
print(matches.shape)
print(deliveries.shape)
print("Matches DataFrame:")
print(matches.head(5))

print("\nDeliveries DataFrame:")
print(deliveries.head(5))
# Out:
# (1095, 20)
# (260920, 17)
# Matches DataFrame:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper
# 4          20.0          N    NaN  BF Bowden     K Hariharan
#
# Deliveries DataFrame:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN
# 2           1       wides          0              NaN            NaN     NaN
# 3           0         NaN          0              NaN            NaN     NaN
# 4           0         NaN          0              NaN            NaN     NaN

# %% [markdown]
# ## **This is a sample toy data for testing Publish and Subscribe Flow in pubsub**

# %%
sample_match = matches.sample(1, random_state=42).to_dict(orient="records")[0]
print ("Sample Match Record:")
print (sample_match)
message = {
    "event_type": "match",
    "payload": sample_match
}
data = json.dumps(message, default=str).encode("utf-8")
future = publisher.publish(topic_path, data)
print(f"Published message ID: {future.result()}")
print(json.dumps(message, indent=2)[:600])

subscriber = pubsub_v1.SubscriberClient()
subscription_path = subscriber.subscription_path(PROJECT_ID, SUBSCRIPTION_ID)
response = subscriber.pull(
    request={"subscription": subscription_path, "max_messages": 10}
)
for received_message in response.received_messages:
    print(f"Received message: {received_message.message.data.decode('utf-8')}")
    subscriber.acknowledge(
        request={
            "subscription": subscription_path,
            "ack_ids": [received_message.ack_id]
        }
    )
# Out:
# Sample Match Record:
# {'id': 980933, 'season': '2016', 'city': 'Delhi', 'date': '2016-04-23', 'match_type': 'League', 'player_of_match': 'SV Samson', 'venue': 'Feroz Shah Kotla', 'team1': 'Delhi Daredevils', 'team2': 'Mumbai Indians', 'toss_winner': 'Mumbai Indians', 'toss_decision': 'field', 'winner': 'Delhi Daredevils', 'result': 'runs', 'result_margin': 10.0, 'target_runs': 165.0, 'target_overs': 20.0, 'super_over': 'N', 'method': nan, 'umpire1': 'S Ravi', 'umpire2': 'C Shamshuddin'}
# Published message ID: 16958152961889023
# {
#   "event_type": "match",
#   "payload": {
#     "id": 980933,
#     "season": "2016",
#     "city": "Delhi",
#     "date": "2016-04-23",
#     "match_type": "League",
#     "player_of_match": "SV Samson",
#     "venue": "Feroz Shah Kotla",
#     "team1": "Delhi Daredevils",
#     "team2": "Mumbai Indians",
#     "toss_winner": "Mumbai Indians",
#     "toss_decision": "field",
#     "winner": "Delhi Daredevils",
#     "result": "runs",
#     "result_margin": 10.0,
#     "target_runs": 165.0,
#     "target_overs": 20.0,
#     "super_over": "N",
#     "method": NaN,
#     "umpire1": "S Ravi",
#     "umpire2": "C Shamshuddin"
#   }
# }
# C:\Users\zeond\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\auth\_default.py:108: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# Received message: {"eventType": "deliveries", "payload": {"match_id": "336016", "inning": "1", "batting_team": "Royal Challengers Bangalore", "bowling_team": "Kings XI Punjab", "over": "12", "ball": "2", "batter": "MV Boucher", "bowler": "PP Chawla", "non_striker": "R Dravid", "batsman_runs": "1", "extra_runs": "0", "total_runs": "1", "extras_type": "", "is_wicket": "0", "player_dismissed": "NA", "dismissal_kind": "NA", "fielder": "NA"}}
# Received message: {"eventType": "deliveries", "payload": {"match_id": "392197", "inning": "2", "batting_team": "Kolkata Knight Riders", "bowling_team": "Mumbai Indians", "over": "11", "ball": "5", "batter": "Yashpal Singh", "bowler": "SR Tendulkar", "non_striker": "SC Ganguly", "batsman_runs": "1", "extra_runs": "0", "total_runs": "1", "extras_type": "", "is_wicket": "0", "player_dismissed": "NA", "dismissal_kind": "NA", "fielder": "NA"}}
# Received message: {"eventType": "deliveries", "payload": {"match_id": "392197", "inning": "2", "batting_team": "Kolkata Knight Riders", "bowling_team": "Mumbai Indians", "over": "11", "ball": "6", "batter": "SC Ganguly", "bowler": "SR Tendulkar", "non_striker": "Yashpal Singh", "batsman_runs": "1", "extra_runs": "0", "total_runs": "1", "extras_type": "", "is_wicket": "0", "player_dismissed": "NA", "dismissal_kind": "NA", "fielder": "NA"}}
# Received message: {"eventType": "deliveries", "payload": {"match_id": "392197", "inning": "2", "batting_team": "Kolkata Knight Riders", "bowling_team": "Mumbai Indians", "over": "12", "ball": "6", "batter": "LR Shukla", "bowler": "AM Nayar", "non_striker": "Yashpal Singh", "batsman_runs": "0", "extra_runs": "0", "total_runs": "0", "extras_type": "", "is_wicket": "0", "player_dismissed": "NA", "dismissal_kind": "NA", "fielder": "NA"}}
# Received message: {"eventType": "deliveries", "payload": {"match_id": "392197", "inning": "2", "batting_team": "Kolkata Knight Riders", "bowling_team": "Mumbai Indians", "over": "13", "ball": "1", "batter": "Yashpal Singh", "bowler": "DJ Bravo", "non_striker": "LR Shukla", "batsman_runs": "2", "extra_runs": "0", "total_runs": "2", "extras_type": "", "is_wicket": "0", "player_dismissed": "NA", "dismissal_kind": "NA", "fielder": "NA"}}
# Received message: {"eventType": "deliveries", "payload": {"match_id": "392198", "inning": "1", "batting_team": "Delhi Daredevils", "bowling_team": "Rajasthan Royals", "over": "1", "ball": "6", "batter": "G Gambhir", "bowler": "Kamran Khan", "non_striker": "V Sehwag", "batsman_runs": "4", "extra_runs": "0", "total_runs": "4", "extras_type": "", "is_wicket": "0", "player_dismissed": "NA", "dismissal_kind": "NA", "fielder": "NA"}}
# Received message: {"eventType": "deliveries", "payload": {"match_id": "392198", "inning": "1", "batting_team": "Delhi Daredevils", "bowling_team": "Rajasthan Royals", "over": "2", "ball": "1", "batter": "V Sehwag", "bowler": "AD Mascarenhas", "non_striker": "G Gambhir", "batsman_runs": "4", "extra_runs": "0", "total_runs": "4", "extras_type": "", "is_wicket": "0", "player_dismissed": "NA", "dismissal_kind": "NA", "fielder": "NA"}}
# Received message: {"eventType": "deliveries", "payload": {"match_id": "392198", "inning": "1", "batting_team": "Delhi Daredevils", "bowling_team": "Rajasthan Royals", "over": "2", "ball": "2", "batter": "V Sehwag", "bowler": "AD Mascarenhas", "non_striker": "G Gambhir", "batsman_runs": "1", "extra_runs": "0", "total_runs": "1", "extras_type": "", "is_wicket": "0", "player_dismissed": "NA", "dismissal_kind": "NA", "fielder": "NA"}}
# Received message: {"eventType": "deliveries", "payload": {"match_id": "392198", "inning": "1", "batting_team": "Delhi Daredevils", "bowling_team": "Rajasthan Royals", "over": "5", "ball": "2", "batter": "TM Dilshan", "bowler": "MM Patel", "non_striker": "AB de Villiers", "batsman_runs": "1", "extra_runs": "0", "total_runs": "1", "extras_type": "", "is_wicket": "0", "player_dismissed": "NA", "dismissal_kind": "NA", "fielder": "NA"}}
# Received message: {"eventType": "deliveries", "payload": {"match_id": "392198", "inning": "1", "batting_team": "Delhi Daredevils", "bowling_team": "Rajasthan Royals", "over": "5", "ball": "3", "batter": "AB de Villiers", "bowler": "MM Patel", "non_striker": "TM Dilshan", "batsman_runs": "1", "extra_runs": "0", "total_runs": "1", "extras_type": "", "is_wicket": "0", "player_dismissed": "NA", "dismissal_kind": "NA", "fielder": "NA"}}

# %% [markdown]
# ## **Push all the dataset to PubSub broker service**
# *Two event types are maitained "matches" and "deliveries"*
# - matches event_type for Matches dataset queue
# - deliveries event_type for Deliveries  dataset

# %%
def publish_csv(file_path: str, event_type: str) -> int:
    """
    Reads a CSV and publishes each row as:
    {
      "eventType": "<event_type>",
      "payload": {<csv row as JSON>}
    }
    Returns number of published messages.
    """
    p = pathlib.Path(file_path)
    if not p.exists():
        raise FileNotFoundError(f"CSV not found: {p.resolve()}")

    futures = []
    with p.open("r", newline="", encoding="utf-8") as f:
        reader = csv.DictReader(f)
        for row in reader:

            message_obj = {
                "eventType": event_type,
                "payload": row,          
            }
            data_bytes = json.dumps(message_obj, ensure_ascii=False).encode("utf-8")

            # Publish message
            fut = publisher.publish(
                topic_path,
                data=data_bytes,
                source_file=p.name,
                eventType=event_type
            )
            futures.append(fut)

    # Ensure all publishes complete (raise on error)
    for fut in futures:
        fut.result()
    return len(futures)

# Publish both Datasets
count_matches = publish_csv(matches_FILE, "match")
count_deliveries = publish_csv(deliveries_FILE, "deliveries")

print(f"Published {count_matches} 'match' messages and {count_deliveries} 'deliveries' messages.")
# Out:
# Published 1095 'match' messages and 260920 'deliveries' messages.
