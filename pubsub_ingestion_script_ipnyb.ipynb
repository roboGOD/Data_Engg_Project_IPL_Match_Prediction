# %% [markdown]
# <a href="https://colab.research.google.com/github/muuse07iisc/Data_Engg_Project_IPL_Match_Prediction/blob/main/pubsub_ingestion_script_ipnyb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
