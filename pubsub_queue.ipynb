# %% [markdown]
# Install the dependency packages

# %%
# !python -m venv .venv
# !.venv\Scripts\Activate.ps1
# !pip install google-cloud-pubsub python-dotenv pandas
# Out:
# Requirement already satisfied: google-cloud-pubsub in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.33.0)
# Requirement already satisfied: python-dotenv in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.2.1)
# Requirement already satisfied: pandas in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.3)
# Requirement already satisfied: grpcio<2.0.0,>=1.51.3 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-cloud-pubsub) (1.76.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-cloud-pubsub) (2.42.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2.28.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.0 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-cloud-pubsub) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-cloud-pubsub) (6.33.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-cloud-pubsub) (0.14.3)
# Requirement already satisfied: grpcio-status>=1.33.2 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-cloud-pubsub) (1.76.0)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-cloud-pubsub) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.27.0 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-cloud-pubsub) (1.38.0)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (1.71.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2.32.3)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (4.9.1)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from grpcio<2.0.0,>=1.51.3->google-cloud-pubsub) (4.13.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-api>=1.27.0->google-cloud-pubsub) (8.7.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-sdk>=1.27.0->google-cloud-pubsub) (0.59b0)
# Requirement already satisfied: six>=1.5 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.27.0->google-cloud-pubsub) (3.23.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zeond\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2025.4.26)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\zeond\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# Import Function

# %%
import pandas as pd
import json, pathlib, os, csv
from google.cloud import pubsub_v1

# %% [markdown]
# Initialization

# %%
PROJECT_ID = "iisc-data-engineering-project"
TOPIC_ID = "match_data"
SUBSCRIPTION_ID = "match_data-sub"
matches_FILE = "matches.csv"
deliveries_FILE = "deliveries.csv"
batch_setting = pubsub_v1.types.BatchSettings(
    max_bytes=1024,  # Maximum bytes to batch
    max_messages=1000,  # Maximum number of messages to batch 
    max_latency=0.5,  # Maximum latency in seconds
)
publisher = pubsub_v1.PublisherClient(batch_settings=batch_setting)
topic_path = publisher.topic_path(PROJECT_ID, TOPIC_ID)
# Out:
# C:\Users\zeond\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\auth\_default.py:108: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %% [markdown]
# Two dataset are used of the following structure. The dataset is from IPL 2008-2024
# 1. Matches  - Contains Match level data, Each row represents a single IPL match, including venue, teams, toss results, match outcomes, and player awards.
# 2. Deliveries - Each row represents one delivery (ball) in an IPL match. It links to matches.csv via the match_id column.

# %%
matches = pd.read_csv(matches_FILE)
deliveries = pd.read_csv(deliveries_FILE)

print("Matches DataFrame:")
print(matches.head(5))

print("\nDeliveries DataFrame:")
print(deliveries.head(5))
# Out:
# Matches DataFrame:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper
# 4          20.0          N    NaN  BF Bowden     K Hariharan
#
# Deliveries DataFrame:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN
# 2           1       wides          0              NaN            NaN     NaN
# 3           0         NaN          0              NaN            NaN     NaN
# 4           0         NaN          0              NaN            NaN     NaN

# %% [markdown]
# This is a sample toy data for testing Publish and Subsribe Flow in pubsub

# %%
sample_match = matches.sample(1, random_state=42).to_dict(orient="records")[0]
print ("Sample Match Record:")
print (sample_match)
message = {
    "event_type": "match",
    "payload": sample_match
}
data = json.dumps(message, default=str).encode("utf-8")
future = publisher.publish(topic_path, data)
print(f"Published message ID: {future.result()}")
print(json.dumps(message, indent=2)[:600])

subscriber = pubsub_v1.SubscriberClient()
subscription_path = subscriber.subscription_path(PROJECT_ID, SUBSCRIPTION_ID)
response = subscriber.pull(
    request={"subscription": subscription_path, "max_messages": 10}
)
for received_message in response.received_messages:
    print(f"Received message: {received_message.message.data.decode('utf-8')}")
    subscriber.acknowledge(
        request={
            "subscription": subscription_path,
            "ack_ids": [received_message.ack_id]
        }
    )
# Out:
# Sample Match Record:
# {'id': 980933, 'season': '2016', 'city': 'Delhi', 'date': '2016-04-23', 'match_type': 'League', 'player_of_match': 'SV Samson', 'venue': 'Feroz Shah Kotla', 'team1': 'Delhi Daredevils', 'team2': 'Mumbai Indians', 'toss_winner': 'Mumbai Indians', 'toss_decision': 'field', 'winner': 'Delhi Daredevils', 'result': 'runs', 'result_margin': 10.0, 'target_runs': 165.0, 'target_overs': 20.0, 'super_over': 'N', 'method': nan, 'umpire1': 'S Ravi', 'umpire2': 'C Shamshuddin'}
# Published message ID: 16956330235317210
# {
#   "event_type": "match",
#   "payload": {
#     "id": 980933,
#     "season": "2016",
#     "city": "Delhi",
#     "date": "2016-04-23",
#     "match_type": "League",
#     "player_of_match": "SV Samson",
#     "venue": "Feroz Shah Kotla",
#     "team1": "Delhi Daredevils",
#     "team2": "Mumbai Indians",
#     "toss_winner": "Mumbai Indians",
#     "toss_decision": "field",
#     "winner": "Delhi Daredevils",
#     "result": "runs",
#     "result_margin": 10.0,
#     "target_runs": 165.0,
#     "target_overs": 20.0,
#     "super_over": "N",
#     "method": NaN,
#     "umpire1": "S Ravi",
#     "umpire2": "C Shamshuddin"
#   }
# }
# C:\Users\zeond\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\auth\_default.py:108: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# Received message: {"eventType": "deliveries", "payload": {"match_id": "1136595", "inning": "1", "batting_team": "Royal Challengers Bangalore", "bowling_team": "Chennai Super Kings", "over": "13", "ball": "3", "batter": "TG Southee", "bowler": "Harbhajan Singh", "non_striker": "C de Grandhomme", "batsman_runs": "0", "extra_runs": "0", "total_runs": "0", "extras_type": "", "is_wicket": "0", "player_dismissed": "NA", "dismissal_kind": "NA", "fielder": "NA"}}
# Received message: {"eventType": "deliveries", "payload": {"match_id": "1136594", "inning": "2", "batting_team": "Mumbai Indians", "bowling_team": "Kings XI Punjab", "over": "15", "ball": "4", "batter": "KH Pandya", "bowler": "AJ Tye", "non_striker": "RG Sharma", "batsman_runs": "0", "extra_runs": "1", "total_runs": "1", "extras_type": "wides", "is_wicket": "0", "player_dismissed": "NA", "dismissal_kind": "NA", "fielder": "NA"}}
# Received message: {"eventType": "deliveries", "payload": {"match_id": "1136594", "inning": "2", "batting_team": "Mumbai Indians", "bowling_team": "Kings XI Punjab", "over": "15", "ball": "5", "batter": "KH Pandya", "bowler": "AJ Tye", "non_striker": "RG Sharma", "batsman_runs": "4", "extra_runs": "0", "total_runs": "4", "extras_type": "", "is_wicket": "0", "player_dismissed": "NA", "dismissal_kind": "NA", "fielder": "NA"}}
# Received message: {"eventType": "deliveries", "payload": {"match_id": "1136596", "inning": "1", "batting_team": "Delhi Daredevils", "bowling_team": "Sunrisers Hyderabad", "over": "1", "ball": "5", "batter": "PP Shaw", "bowler": "Sandeep Sharma", "non_striker": "SS Iyer", "batsman_runs": "0", "extra_runs": "1", "total_runs": "1", "extras_type": "wides", "is_wicket": "0", "player_dismissed": "NA", "dismissal_kind": "NA", "fielder": "NA"}}
# Received message: {"eventType": "deliveries", "payload": {"match_id": "1136596", "inning": "1", "batting_team": "Delhi Daredevils", "bowling_team": "Sunrisers Hyderabad", "over": "1", "ball": "6", "batter": "PP Shaw", "bowler": "Sandeep Sharma", "non_striker": "SS Iyer", "batsman_runs": "4", "extra_runs": "0", "total_runs": "4", "extras_type": "", "is_wicket": "0", "player_dismissed": "NA", "dismissal_kind": "NA", "fielder": "NA"}}
# Received message: {"eventType": "deliveries", "payload": {"match_id": "1136597", "inning": "1", "batting_team": "Mumbai Indians", "bowling_team": "Kolkata Knight Riders", "over": "0", "ball": "6", "batter": "E Lewis", "bowler": "N Rana", "non_striker": "SA Yadav", "batsman_runs": "0", "extra_runs": "0", "total_runs": "0", "extras_type": "", "is_wicket": "0", "player_dismissed": "NA", "dismissal_kind": "NA", "fielder": "NA"}}
# Received message: {"eventType": "deliveries", "payload": {"match_id": "1136597", "inning": "1", "batting_team": "Mumbai Indians", "bowling_team": "Kolkata Knight Riders", "over": "1", "ball": "1", "batter": "SA Yadav", "bowler": "M Prasidh Krishna", "non_striker": "E Lewis", "batsman_runs": "0", "extra_runs": "0", "total_runs": "0", "extras_type": "", "is_wicket": "0", "player_dismissed": "NA", "dismissal_kind": "NA", "fielder": "NA"}}
# Received message: {"eventType": "deliveries", "payload": {"match_id": "1136597", "inning": "2", "batting_team": "Kolkata Knight Riders", "bowling_team": "Mumbai Indians", "over": "4", "ball": "2", "batter": "RV Uthappa", "bowler": "MJ McClenaghan", "non_striker": "N Rana", "batsman_runs": "0", "extra_runs": "0", "total_runs": "0", "extras_type": "", "is_wicket": "0", "player_dismissed": "NA", "dismissal_kind": "NA", "fielder": "NA"}}
# Received message: {"eventType": "deliveries", "payload": {"match_id": "1136597", "inning": "2", "batting_team": "Kolkata Knight Riders", "bowling_team": "Mumbai Indians", "over": "4", "ball": "3", "batter": "RV Uthappa", "bowler": "MJ McClenaghan", "non_striker": "N Rana", "batsman_runs": "1", "extra_runs": "0", "total_runs": "1", "extras_type": "", "is_wicket": "0", "player_dismissed": "NA", "dismissal_kind": "NA", "fielder": "NA"}}
# Received message: {"event_type": "match", "payload": {"id": 980933, "season": "2016", "city": "Delhi", "date": "2016-04-23", "match_type": "League", "player_of_match": "SV Samson", "venue": "Feroz Shah Kotla", "team1": "Delhi Daredevils", "team2": "Mumbai Indians", "toss_winner": "Mumbai Indians", "toss_decision": "field", "winner": "Delhi Daredevils", "result": "runs", "result_margin": 10.0, "target_runs": 165.0, "target_overs": 20.0, "super_over": "N", "method": NaN, "umpire1": "S Ravi", "umpire2": "C Shamshuddin"}}

# %% [markdown]
# Push all the Matches.CSV to PubSub broker service

# %%
def publish_csv(file_path: str, event_type: str) -> int:
    """
    Reads a CSV and publishes each row as:
    {
      "eventType": "<event_type>",
      "payload": {<csv row as JSON>}
    }
    Returns number of published messages.
    """
    p = pathlib.Path(file_path)
    if not p.exists():
        raise FileNotFoundError(f"CSV not found: {p.resolve()}")

    futures = []
    with p.open("r", newline="", encoding="utf-8") as f:
        reader = csv.DictReader(f)
        for row in enumerate(reader):
           
            message_obj = {
                "eventType": event_type,
                "payload": row,           # row already dict from DictReader
            }
            data_bytes = json.dumps(message_obj, ensure_ascii=False).encode("utf-8")

            # Optional attributes for filtering/monitoring
            fut = publisher.publish(
                topic_path,
                data=data_bytes,
                source_file=p.name,
                eventType=event_type
            )
            futures.append(fut)

    # Ensure all publishes complete (raise on error)
    for fut in futures:
        fut.result()
    return len(futures)

# Publish both CSVs
count_matches = publish_csv(matches_FILE, "match")
count_deliveries = publish_csv(deliveries_FILE, "deliveries")

print(f"Published {count_matches} 'match' messages and {count_deliveries} 'deliveries' messages.")
